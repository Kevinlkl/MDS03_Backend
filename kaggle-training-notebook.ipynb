# %%
# !git clone https://github.com/Kevinlkl/MDS03_Backend.git
# Out:
# Cloning into 'MDS03_Backend'...
# remote: Enumerating objects: 21447, done.
# remote: Counting objects: 100% (3734/3734), done.
# remote: Compressing objects: 100% (3718/3718), done.
# remote: Total 21447 (delta 20), reused 3721 (delta 12), pack-reused 17713 (from 1)
# Receiving objects: 100% (21447/21447), 566.15 MiB | 37.49 MiB/s, done.
# Resolving deltas: 100% (1294/1294), done.
# Updating files: 100% (9532/9532), done.

# %%
cd '/kaggle/working/MDS03_Backend'
# Out:
# /kaggle/working/MDS03_Backend

# %%
# !python model.py train --data-root Dataset/T1 --output-dir outputs/sd_t1_mri --base-model runwayml/stable-diffusion-v1-5 --epochs 5 --batch-size 2 --image-size 256 --fp16
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# tokenizer_config.json: 100%|███████████████████| 806/806 [00:00<00:00, 2.49MB/s]
# vocab.json: 1.06MB [00:00, 31.7MB/s]
# merges.txt: 525kB [00:00, 115MB/s]
# ...
# config.json: 100%|█████████████████████████████| 617/617 [00:00<00:00, 3.18MB/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# text_encoder/model.safetensors: 100%|█████████| 492M/492M [00:01<00:00, 328MB/s]
# Loading weights: 100%|█| 196/196 [00:00<00:00, 1780.61it/s, Materializing param=
# CLIPTextModel LOAD REPORT from: runwayml/stable-diffusion-v1-5
# ...

# %%
# Zip output files before session ends
# !zip -r /kaggle/working/output.zip /kaggle/working/MDS03_Backend/outputs
# Out:
#   adding: kaggle/working/MDS03_Backend/outputs/ (stored 0%)
#   adding: kaggle/working/MDS03_Backend/outputs/sd_t1_mri/ (stored 0%)
#   adding: kaggle/working/MDS03_Backend/outputs/sd_t1_mri/checkpoint-6500/ (stored 0%)
#   adding: kaggle/working/MDS03_Backend/outputs/sd_t1_mri/checkpoint-6500/lora/ (stored 0%)
#   adding: kaggle/working/MDS03_Backend/outputs/sd_t1_mri/checkpoint-6500/lora/pytorch_lora_weights.safetensors (deflated 6%)
#   adding: kaggle/working/MDS03_Backend/outputs/sd_t1_mri/checkpoint-4500/ (stored 0%)
#   adding: kaggle/working/MDS03_Backend/outputs/sd_t1_mri/checkpoint-4500/lora/ (stored 0%)
#   adding: kaggle/working/MDS03_Backend/outputs/sd_t1_mri/checkpoint-4500/lora/pytorch_lora_weights.safetensors (deflated 6%)
#   adding: kaggle/working/MDS03_Backend/outputs/sd_t1_mri/base_model.txt (stored 0%)
#   adding: kaggle/working/MDS03_Backend/outputs/sd_t1_mri/checkpoint-2000/ (stored 0%)
# ...

# %%
import torch
from model import generate
import argparse

# Create a mock args object
args = argparse.Namespace(
    base_model="runwayml/stable-diffusion-v1-5",
    lora_path="/kaggle/input/your-dataset-name/checkpoint-7500/lora",
    output_dir="outputs/generated",
    prompt="High-resolution axial T1-weighted brain MRI, [glioma with peri-tumoral edema], [hypointense lesion], neuroimaging, sharp anatomical detail, [DICOM style], 8k, clinical grade, authentic medical scan texture, noise-free background",
    negative_prompt="vignette, gray background, noise, artifacts, blur, hazy, texture in background, low contrast, colorful",
    num_images=100,
    inference_steps=40,
    guidance_scale=7.5,
    image_size=256,
    fp32=True,
    clean_background=True,
    model_path="outputs/sd_t1_mri" # fallback if lora_path is empty
)

# Run it
generate(args)
# Out:
# Running cells with '.venv (3.11.9) (Python 3.11.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"d:/C2001 Y3S2/FYP/backend/MDS03_Backend/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

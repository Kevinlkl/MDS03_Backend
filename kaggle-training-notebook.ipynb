# %%
# !git clone https://github.com/Kevinlkl/MDS03_Backend.git
# Out:
# Cloning into 'MDS03_Backend'...
# remote: Enumerating objects: 25173, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 25173 (delta 24), reused 23 (delta 19), pack-reused 25141 (from 4)
# Receiving objects: 100% (25173/25173), 919.90 MiB | 9.43 MiB/s, done.
# Resolving deltas: 100% (1324/1324), done.

# %%
cd '/kaggle/working/MDS03_Backend'
# Out:
# /kaggle/working/MDS03_Backend

# %%
import os
# This will show you exactly what is inside your dataset folder
print(os.listdir('/kaggle/input/datasets/sohcheesheng/t1-dataset-1/'))
# Out:
# ['T1']

# %%
# !python model.py train --data-root /kaggle/input/datasets/sohcheesheng/t1-dataset-1/T1 --output-dir sd_t1_mri --base-model runwayml/stable-diffusion-v1-5 --epochs 10 --batch-size 2 --image-size 256
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Total samples: 3064
# Train samples: 2452
# Validation samples: 612
# tokenizer_config.json: 100%|███████████████████| 806/806 [00:00<00:00, 3.33MB/s]
# vocab.json: 1.06MB [00:00, 28.5MB/s]
# merges.txt: 525kB [00:00, 100MB/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ...
# config.json: 100%|█████████████████████████████| 617/617 [00:00<00:00, 2.25MB/s]
# text_encoder/model.safetensors: 100%|█████████| 492M/492M [00:01<00:00, 287MB/s]
# Loading weights: 100%|█| 196/196 [00:00<00:00, 1911.35it/s, Materializing param=
# ...

# %%
# Zip output files before session ends
# !zip -r /kaggle/working/output.zip /kaggle/working/MDS03_Backend/sd_t1_mri
# Out:
# updating: kaggle/working/MDS03_Backend/sd_t1_mri/ (stored 0%)
# updating: kaggle/working/MDS03_Backend/sd_t1_mri/checkpoint-3000/ (stored 0%)
# updating: kaggle/working/MDS03_Backend/sd_t1_mri/checkpoint-3000/lora/ (stored 0%)
# updating: kaggle/working/MDS03_Backend/sd_t1_mri/checkpoint-3000/lora/pytorch_lora_weights.safetensors (deflated 6%)
# updating: kaggle/working/MDS03_Backend/sd_t1_mri/checkpoint-5000/ (stored 0%)
# updating: kaggle/working/MDS03_Backend/sd_t1_mri/checkpoint-5000/lora/ (stored 0%)
# updating: kaggle/working/MDS03_Backend/sd_t1_mri/checkpoint-5000/lora/pytorch_lora_weights.safetensors (deflated 6%)
# updating: kaggle/working/MDS03_Backend/sd_t1_mri/checkpoint-11500/ (stored 0%)
# updating: kaggle/working/MDS03_Backend/sd_t1_mri/checkpoint-11500/lora/ (stored 0%)
# updating: kaggle/working/MDS03_Backend/sd_t1_mri/checkpoint-11500/lora/pytorch_lora_weights.safetensors (deflated 7%)
# updating: kaggle/working/MDS03_Backend/sd_t1_mri/checkpoint-500/ (stored 0%)
# ...

# %%
# !python model.py generate --base-model runwayml/stable-diffusion-v1-5 --lora-path "sd_t1_mri/best_model/lora" --output-dir outputs/generated --prompt "axial T1-weighted brain MRI scan showing glioma, medical imaging, grayscale, sharp anatomical detail" --clean-background --num-images 500 --image-size 256
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Using device for generation: CUDA
# ...
# Loading weights:   0%|                                  | 0/196 [00:00<?, ?it/s]
# Loading weights:   1%| | 1/196 [00:00<00:00, 12052.60it/s, Materializing param=t
# Loading weights:   1%| | 1/196 [00:00<00:00, 748.45it/s, Materializing param=tex
# Loading weights:   1%| | 2/196 [00:00<00:00, 836.60it/s, Materializing param=tex
# Loading weights:   1%| | 2/196 [00:00<00:00, 650.33it/s, Materializing param=tex
# Loading weights:   2%| | 3/196 [00:00<00:00, 578.84it/s, Materializing param=tex
# Loading weights:   2%| | 3/196 [00:00<00:00, 532.63it/s, Materializing param=tex
# ...

# %%
# !pip install pytorch-fid

# %%
# !python -m pytorch_fid "/kaggle/input/datasets/sohcheesheng/t1-dataset-1/T1/Glioma_256_T1weighted/" "outputs/generated" --device cuda
# Out:
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100%|███████████████████████████████████████| 91.2M/91.2M [00:00<00:00, 236MB/s]
# ...
# 100%|███████████████████████████████████████████| 10/10 [00:02<00:00,  4.26it/s]
# FID:  189.37255058761298
